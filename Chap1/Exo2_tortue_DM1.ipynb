# %% [markdown]
# <img src="https://raw.githubusercontent.com/lyceeHM/Terminale_Spe/master/python_lycee.png">
# <div id="titre">
# <h1 style="color:white;
#   font-family:Comic Sans MS;
#   font-size:3em;
#   background-color:black;
#   text-align:center;
#   padding:5px">Devoir Maison n°1</h1>
# <div style="font-family:Comic Sans MS; background-color:#888;box-shadow: 8px 8px 0px #aaa; text-align:center; width: 50%; color:white">Seconde : Chapitre 1 - Nombres</div>
# </div>

# %% [markdown]
# <h1 style="font-size:3em;font-weight:bold">Exercice n°2</h1>

# %%
from turtle import *
speed('fast')
shape('turtle')

# %%
setworldcoordinates(-30, -60, 30, 65)
for i in range(1, 101):
    lt(89)
    fd(i)
done()
